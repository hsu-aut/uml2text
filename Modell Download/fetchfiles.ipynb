# %% [markdown]
# Download a single file

# %%
import requests

url = "https://raw.githubusercontent.com/09421/Track-A-Bus/master/1%20-%20Systemdesign/3%20-%204th/04_Systemdesign/Diagrammer/SSD/UC1.2%20Simple%20Sequence%20Diagram.png"
response = requests.get(url)

if response.status_code == 200:
    with open("UC1.2_Simple_Sequence_Diagram.png", "wb") as file:
        file.write(response.content)
    print("Download complete.")
else:
    print("Failed to download file. Status code:", response.status_code)
# Out:
# Download complete.

# %% [markdown]
# Download all files from a list of urls read from a .csv file

# %%
import pandas as pd
import os
import requests


# Load the CSV file from the subfolder 'Beispielmodelle'
file_path = 'Beispielmodelle/UMLFiles_List_V2.0.csv'
df_files = pd.read_csv(file_path, sep=',')
print(df_files.head())

# Reformulate the link to be downloadable
df_files['Download Link'] = df_files['Model Link - Github'].str.replace('www.github.com', 'raw.githubusercontent.com').str.replace('/tree/', '/')
failed_downloads = []
# Example of reformulated link
print(df_files['Download Link'].head())


# Create directories if they don't exist
directories = ['JPG', 'PNG', 'UML', 'XMI', 'OTHER']
for directory in directories:
    if not os.path.exists(directory):
        os.makedirs(directory)

# Download the first 20 files
for link in df_files['Download Link']:
    file_name = link.split('/')[-1]
    # Determine the subfolder based on file extension
    _, extension = os.path.splitext(file_name)
    extension = extension.lower()
    if extension == '.jpg':
        subfolder = 'JPG'
    elif extension == '.png':
        subfolder = 'PNG'
    elif extension == '.uml':
        subfolder = 'UML'
    elif extension == '.xmi':
        subfolder = 'XMI'
    else:
        subfolder = 'OTHER'
    
    # Check if file already exists in the respective subfolder, if so, change the file name
    file_path = os.path.join(subfolder, file_name)
    if os.path.exists(file_path):
        base, extension = os.path.splitext(file_name)
        counter = 1
        new_file_name = f"{base}_{counter}{extension}"
        new_file_path = os.path.join(subfolder, new_file_name)
        while os.path.exists(new_file_path):
            counter += 1
            new_file_name = f"{base}_{counter}{extension}"
            new_file_path = os.path.join(subfolder, new_file_name)
        file_name = new_file_name
        file_path = new_file_path

    response = requests.get(link)
    if response.status_code == 200:
        # Determine the subfolder based on file extension
        _, extension = os.path.splitext(file_name)
        extension = extension.lower()
        if extension == '.jpg':
            subfolder = 'JPG'
        elif extension == '.png':
            subfolder = 'PNG'
        elif extension == '.uml':
            subfolder = 'UML'
        elif extension == '.xmi':
            subfolder = 'XMI'
        else:
            subfolder = 'OTHER'
        
        # Save the file in the appropriate subfolder
        file_path = os.path.join(subfolder, file_name)
        with open(file_path, "wb") as file:
            file.write(response.content)
        print(f"Downloaded: {file_path}")
    else:
        print(f"Failed to download {file_name}. Status code:", response.status_code)
        # Add the failed URL to the list
        failed_downloads.append(link)

    # Write the list of failed downloads to a file
    with open("failedDownloads.txt", "w") as f:
        for item in failed_downloads:
            f.write("%s\n" % item)
# Out:
#                            Project  \
# 0      0-complexity/ovcdoc_public/
# 1  0003088/libelektra-qt-gui-test/
# 2                     00s/deadman/
# 3            01db0y/ImageUploader/
# 4                  01db0y/ShareIt/
#
#                                  Model Link - Github
# 0  https://www.github.com/0-complexity/ovcdoc_pub...
# 1  https://www.github.com/0003088/libelektra-qt-g...
# 2  https://www.github.com/00s/deadman/tree/master...
# 3  https://www.github.com/01db0y/ImageUploader/tr...
# 4  https://www.github.com/01db0y/ShareIt/tree/mas...
# 0    https://raw.githubusercontent.com/0-complexity...
# 1    https://raw.githubusercontent.com/0003088/libe...
# 2    https://raw.githubusercontent.com/00s/deadman/...
# 3    https://raw.githubusercontent.com/01db0y/Image...
# 4    https://raw.githubusercontent.com/01db0y/Share...
# Name: Download Link, dtype: object
# Failed to download AdminArchitecture.png. Status code: 404
# Downloaded: XMI\overview_plugins.xmi
# Downloaded: PNG\zombie-game Activity Diagram.png
# Downloaded: PNG\Class Diagram1.png
# Downloaded: PNG\Class Diagram1_1.png
# Downloaded: UML\LLD.uml
# Downloaded: PNG\DecoratorDesignPattern.png
# Downloaded: UML\Channel.uml
# Failed to download mapClassDiagram.png. Status code: 404
# Downloaded: PNG\080419A - ClassDiagram_v_1_0_0.png
# Downloaded: UML\UML Diagram.uml
# Downloaded: JPG\Use_Case_Diagram.jpg
# Downloaded: PNG\UC1 Simple Sequence Diagram.png
# Downloaded: PNG\UC1.1 Simple Sequence Diagram.png
# Downloaded: PNG\UC1.2 Simple Sequence Diagram.png
# Downloaded: JPG\Use_Case_Diagram_1.jpg
# Downloaded: JPG\Use_Case_Diagram_2.jpg
# Downloaded: JPG\Use_Case_Diagram_3.jpg
# Downloaded: JPG\Use_Case_Diagram_4.jpg
# Downloaded: JPG\Administrator hjemmeside - klassediagram.jpg
# Downloaded: JPG\Mobil applikation - Klassediagram.jpg
# Downloaded: JPG\Simulator - Klassediagram.jpg
# Downloaded: JPG\Use_Case_Diagram_5.jpg
# Downloaded: XMI\abstrDesing.xmi
# Failed to download Package_1059.uml. Status code: 404
# Failed to download Package_1105.uml. Status code: 404
# Failed to download Package_1205.uml. Status code: 404
# Failed to download Package_1206.uml. Status code: 404
# Failed to download Package_1207.uml. Status code: 404
# Failed to download Package_1208.uml. Status code: 404
# Failed to download Package_1234.uml. Status code: 404
# Failed to download Package_1235.uml. Status code: 404
# Failed to download Package_1237.uml. Status code: 404
# Failed to download Package_2239.uml. Status code: 404
# Failed to download Package1_1059.uml. Status code: 404
# Failed to download Package1_1105.uml. Status code: 404
# Failed to download Package1_1205.uml. Status code: 404
# Failed to download Package1_1208.uml. Status code: 404
# Failed to download Package1_1234.uml. Status code: 404
# Failed to download Package1_1235.uml. Status code: 404
# Failed to download Package2_1234.uml. Status code: 404
# Failed to download Package3_1234.uml. Status code: 404
# Failed to download Package4_1234.uml. Status code: 404
# Failed to download Package5_1234.uml. Status code: 404
# Failed to download Package6_1234.uml. Status code: 404
# Failed to download Package7_1234.uml. Status code: 404
# Failed to download Package8_1234.uml. Status code: 404
# Failed to download Package9_1234.uml. Status code: 404
# Failed to download UML.uml. Status code: 404
# Failed to download FileHandlerUML.jpg. Status code: 404
# Failed to download ProcessHandlerUML.jpg. Status code: 404
# Failed to download RequestUML.jpg. Status code: 404
# Failed to download ResponseUML.jpg. Status code: 404
# Failed to download assertUML.jpg. Status code: 404
# Failed to download authorizationUML.jpg. Status code: 404
# Downloaded: XMI\101companies-schema.xmi
# Downloaded: PNG\Class Diagram0.png
# Downloaded: UML\Activity Diagram Vending Machine.uml
# Downloaded: UML\State Diagram Vending Machine Choose.uml
# Downloaded: UML\State Diagram Vending MAchine.uml
# Downloaded: JPG\SSD_diagram.jpg
# Downloaded: JPG\class_diagram_1.jpg
# Downloaded: JPG\class_diagram_2.jpg
# Downloaded: PNG\class_diagram1.png
# Downloaded: PNG\class_diagram2.png
# Downloaded: JPG\SSD_diagram_1.jpg
# Downloaded: JPG\class_diagram_1_1.jpg
# Downloaded: JPG\class_diagram_2.1.jpg
# Downloaded: JPG\class_diagram_2.2.jpg
# Downloaded: JPG\class_diagram_2.3.jpg
# Downloaded: JPG\class_diagram_2.4.jpg
# Downloaded: JPG\class_diagram_2_1.jpg
# Downloaded: JPG\SSD_diagram_2.jpg
# Downloaded: JPG\class_diagram_1_2.jpg
# Downloaded: JPG\class_diagram_2_2.jpg
# Downloaded: PNG\architecture.png
# Failed to download SE18_PhamNgocBinh_AssetManagement.Edit_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Edit_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Export_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Export_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Import_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Import_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Order_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Order_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Edit_SequenceDiagram_v2.0_.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Export_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Export_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Import_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Import_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Order_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Order_SequenceDiagram_v2.0_.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement_SequenceDiagram_v1.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Login_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Logout_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Add_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Remove_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Search_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Timebook_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Update_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_ClassDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Edit_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Export_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Order_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Edit_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Export_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Import_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Order_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_VoVanCung_ProductStatistic_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_VoVanCung_StaffStatistic_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_VoVanCung_TotalStatistic_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Login_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Logout_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Add_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Remove_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Search_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Timebook_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Update_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement_SequenceDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_ClassDiagram_v2.0.jpg. Status code: 404
# Failed to download SE18_ClassDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_LeQuangChanh_AssetManagement.Edit_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_LeQuangChanh_AssetManagement.Export_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_LeQuangChanh_AssetManagement.Import_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_LeQuangChanh_AssetManagement.Order_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_LeQuangChanh_AssetManagement_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Login_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Logout_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Add_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Remove_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Search_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Timebook_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Update_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Edit_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Export_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Import_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Order_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_VoVanCung_ProductStatistic_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_VoVanCung_StaffStatistic_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_VoVanCung_TotalStatistic_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Edit_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Export_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Import_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement.Order_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_PhoneManagement_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Edit_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Export_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Import_SequenceDiagram_v2.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Import_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement.Order_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamNgocBinh_AssetManagement_SequenceDiagram_v3.0.png. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Login_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_Account.Logout_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Add_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Remove_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Search_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Timebook_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement.Update_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_PhamAnhDung_StaffManagement_SequenceDiagram_v1.0.jpg. Status code: 404
# Failed to download SE18_VoVanCung_ProductStatistic_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_VoVanCung_StaffStatistic_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_VoVanCung_TotalStatistic_SequenceDiagram_v3.0.jpg. Status code: 404
# Failed to download SE18_ClassDiagram_v3.0.jpg. Status code: 404
# Failed to download actor.uml. Status code: 404
# Failed to download customer.uml. Status code: 404
# Failed to download manager.uml. Status code: 404
# Failed to download page flow.uml. Status code: 404
# Failed to download Class_Diagram_Chanh_v1.0.uml. Status code: 404
# Failed to download SE18_PhamAnhDung_Login&Staff_SequenceDiagram_v1.0.uml. Status code: 404
# Failed to download Class_Diagram_Chanh_v2.0.uml. Status code: 404
# Failed to download reports_sequence_diagram.uml. Status code: 404
# Failed to download SE18_PhamAnhDung_Login&Staff_SequenceDiagram_v2.0.uml. Status code: 404
# Failed to download Class_Diagram_Chanh_v3.0.uml. Status code: 404
# Failed to download sequence_diagram.uml. Status code: 404
# Failed to download SE18_PhamAnhDung_Login&Staff_SequenceDiagram_v3.0.uml. Status code: 404
# Failed to download reports_sequence_diagram.uml. Status code: 404
# Downloaded: UML\char.uml
# Downloaded: PNG\ClassDiagram.png
# Downloaded: UML\dividingBGM.uml
# Downloaded: PNG\activity_diagram1.png
# Downloaded: PNG\activity_diagram2.png
# Downloaded: PNG\activity_diagram3.png
# Downloaded: PNG\classDiagram_1.png
# Downloaded: PNG\state_diagram.png
# Downloaded: PNG\class_diagram.png
# Downloaded: PNG\class_diagram_1.png
# Downloaded: PNG\class_diagram_2.png
# Downloaded: PNG\class_diagram_3.png
# Downloaded: OTHER\class diagram.svg
# Downloaded: OTHER\use case diagram.jpeg
# Downloaded: XMI\projekt_systemu.xmi
# Downloaded: PNG\Class Diagram.png
# Downloaded: OTHER\Deployment Diagram.gif
# Downloaded: OTHER\ClassDiagrams.gif
# Downloaded: JPG\Deployment Diagram.jpg
# Downloaded: OTHER\ClassDiagrams_1.gif
# Downloaded: UML\ibs.uml
# Downloaded: UML\ibs_bak.uml
# Downloaded: UML\ibs-bak.uml
# Failed to download diagram.svg. Status code: 404
# Downloaded: PNG\diagram.png
# Downloaded: PNG\api_uml.png
# Downloaded: PNG\api_uml_public.png
# Downloaded: PNG\simulator_uml.png
# Downloaded: PNG\simulator_uml_public.png
# Downloaded: PNG\uml_api_essenz.png
# Downloaded: PNG\uml_simulator_essenz.png
# Downloaded: UML\classes.uml
# Downloaded: JPG\SequenceDiagramAddMember.jpg
# Downloaded: JPG\SequenceDiagramShowCompactList.jpg
# Downloaded: JPG\classdiagram.jpg
# Downloaded: JPG\SequenceDiagramAddMember_1.jpg
# Downloaded: JPG\SequenceDiagramShowCompactList_1.jpg
# Failed to download model.uml. Status code: 404
# Downloaded: JPG\Klassediagram_a.jpg
# Downloaded: JPG\Klassediagram_e.jpg
# Downloaded: JPG\klassediagram_c.jpg
# Downloaded: JPG\Android Diagram.jpg
# Downloaded: JPG\Servlet Diagram.jpg
# Failed to download ProblemOmraadetKlasseDiagram.png. Status code: 404
# Failed to download ProblemOmraadetKlasseDiagram.png. Status code: 404
# Downloaded: PNG\Diagramas CDU.png
# Downloaded: UML\diagram.uml
# Downloaded: UML\Class Diagram.uml
# Downloaded: UML\schema:APP.uml
# Downloaded: UML\ejercicio 10.uml
# Downloaded: UML\ejercicio 8.uml
# Downloaded: UML\ejercicio 9.uml
# Downloaded: UML\ejercicio11.uml
# Downloaded: UML\ejercicio12.uml
# Downloaded: UML\ejercicio13.uml
# Downloaded: UML\ejercicio14.uml
# Downloaded: UML\ejercicio15.uml
# Downloaded: UML\ejercicio6.uml
# Downloaded: UML\ejercicio6vf.uml
# Downloaded: UML\ejercicio7.uml
# Downloaded: UML\ProyectoFinal.uml
# Downloaded: UML\Ejercicio1.uml
# Downloaded: UML\Ejercicio2.uml
# Downloaded: UML\Ejercicio3.uml
# Downloaded: UML\Ejercicio4.uml
# Downloaded: UML\Ejercicio5.uml
# Downloaded: UML\Ejercicio6_1.uml
# Downloaded: UML\Ejercicio7_1.uml
# Downloaded: UML\ejercicio 10_1.uml
# Downloaded: UML\ejercicio 8_1.uml
# Downloaded: UML\ejercicio 9_1.uml
# Downloaded: UML\ejercicio11_1.uml
# Downloaded: UML\ejercicio12_1.uml
# Downloaded: UML\ejercicio13_1.uml
# Downloaded: UML\ejercicio14_1.uml
# Downloaded: UML\ejercicio15_1.uml
# Downloaded: UML\ejercicio6_2.uml
# Downloaded: UML\ejercicio6vf_1.uml
# Downloaded: UML\ejercicio7_2.uml
# Downloaded: UML\Torres de Hanoi.uml
# Failed to download ModelingProject1.uml. Status code: 404
# Downloaded: PNG\viewarchitecture.png
# Downloaded: UML\plugin.uml
# Downloaded: PNG\SequenceDiagram.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 55
#      52     file_name = new_file_name
#      53     file_path = new_file_path
# ---> 55 response = requests.get(link)
#      56 if response.status_code == 200:
#      57     # Determine the subfolder based on file extension
#      58     _, extension = os.path.splitext(file_name)
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Reinpold\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
